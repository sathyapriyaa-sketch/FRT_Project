# %% [markdown]
# Azure ML & Azure Databricks notebooks by René Bremer (original taken from Databricks website)
#
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# ##### In this notebook the following steps will be excuted:
# 1. Mount blob storage
# 2. Unzip pictures in storage account
# 3. List and show pictures

# %% [markdown]
# #0. Set parameters

# %%
storageaccount="projectspart"
account_key="m6PJRXuZrBQFKRxYu1LsewyJK2s2wo0qE3Db3qQDLkAX/PjjjNpXtdyxZdm6Qne433DySMB7poP4SlPIYS1+pg=="

containername="2000picscifar10"
mountname=containername
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #1. Mount blob storage

# %%
if any(mount.mountPoint == "/mnt/" + mountname for mount in dbutils.fs.mounts()):
  print ("directory " + "/mnt/" + mountname + " is already mounted")
else:
  print ("In case you have a cluster with 0 workers, you need to cancell statement manually after 30 seconds. This is because a spark job is started, which cannot be executed since there are 0 workers. However, the storage is mounted, which can be verified by rerunning cell")
  dbutils.fs.mount(
  source = "wasbs://" + containername + "@" + storageaccount + ".blob.core.windows.net",
  mount_point = "/mnt/" + mountname,
  extra_configs = {"fs.azure.account.key." + storageaccount +".blob.core.windows.net":account_key})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">directory /mnt/2000picscifar10 is already mounted
# </div>

# %% [markdown]
# #2. Unzip pictures

# %%
import zipfile
import os
datafile = "2000pics_cifar10.zip"
datafile_dbfs = os.path.join("/dbfs/mnt/" + mountname, datafile)

print ("unzipping takes approximatelly 2 minutes")
zip_ref = zipfile.ZipFile(datafile_dbfs, 'r')
zip_ref.extractall("/dbfs/mnt/" + mountname)
zip_ref.close()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">unzipping takes approximatelly 2 minutes
# </div>

# %%
# %sh
ls /dbfs/mnt/2000picscifar10
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">2000pics_cifar10.zip
# airplane_1.png
# airplane_10.png
# airplane_100.png
# airplane_101.png
# airplane_102.png
# airplane_103.png
# airplane_104.png
# airplane_105.png
# airplane_106.png
# airplane_107.png
# airplane_108.png
# airplane_109.png
# airplane_11.png
# airplane_110.png
# airplane_111.png
# airplane_112.png
# airplane_113.png
# airplane_114.png
# airplane_115.png
# airplane_116.png
# airplane_117.png
# airplane_118.png
# airplane_119.png
# airplane_12.png
# airplane_120.png
# airplane_121.png
# airplane_122.png
# airplane_123.png
# airplane_124.png
# airplane_125.png
# airplane_126.png
# airplane_127.png
# airplane_128.png
# airplane_129.png
# airplane_13.png
# airplane_130.png
# airplane_131.png
# airplane_132.png
# airplane_133.png
# airplane_134.png
# airplane_135.png
# airplane_136.png
# airplane_137.png
# airplane_138.png
# airplane_139.png
# airplane_14.png
# airplane_140.png
# airplane_141.png
# airplane_142.png
# airplane_143.png
# airplane_144.png
# airplane_145.png
# airplane_146.png
# airplane_147.png
# airplane_148.png
# airplane_149.png
# airplane_15.png
# airplane_150.png
# airplane_151.png
# airplane_152.png
# airplane_153.png
# airplane_154.png
# airplane_155.png
# airplane_156.png
# airplane_157.png
# airplane_158.png
# airplane_159.png
# airplane_16.png
# airplane_160.png
# airplane_161.png
# airplane_162.png
# airplane_163.png
# airplane_164.png
# airplane_165.png
# airplane_166.png
# airplane_167.png
# airplane_168.png
# airplane_169.png
# airplane_17.png
# airplane_170.png
# airplane_171.png
# airplane_172.png
# airplane_173.png
# airplane_174.png
# airplane_175.png
# airplane_176.png
# airplane_177.png
# airplane_178.png
# airplane_179.png
# airplane_18.png
# airplane_180.png
# airplane_181.png
# airplane_182.png
# airplane_183.png
# airplane_184.png
# airplane_185.png
# airplane_186.png
# airplane_187.png
# airplane_188.png
# airplane_189.png
# automobile_185.png
# automobile_186.png
# automobile_187.png
# automobile_188.png
# automobile_189.png
# automobile_19.png
# automobile_190.png
# automobile_191.png
# automobile_192.png
# automobile_193.png
# automobile_194.png
# automobile_195.png
# automobile_196.png
# automobile_197.png
# automobile_198.png
# automobile_199.png
# automobile_2.png
# automobile_20.png
# automobile_200.png
# automobile_21.png
# automobile_22.png
# automobile_23.png
# automobile_24.png
# automobile_25.png
# automobile_26.png
# automobile_27.png
# automobile_28.png
# automobile_29.png
# automobile_3.png
# automobile_30.png
# automobile_31.png
# automobile_32.png
# automobile_33.png
# automobile_34.png
# automobile_35.png
# automobile_36.png
# automobile_37.png
# automobile_38.png
# automobile_39.png
# automobile_4.png
# automobile_40.png
# automobile_41.png
# automobile_42.png
# automobile_43.png
# automobile_44.png
# automobile_45.png
# automobile_46.png
# automobile_47.png
# automobile_48.png
# automobile_49.png
# automobile_5.png
# automobile_50.png
# automobile_51.png
# automobile_52.png
# automobile_53.png
# automobile_54.png
# automobile_55.png
# automobile_56.png
# automobile_57.png
# automobile_58.png
# automobile_59.png
# automobile_6.png
# automobile_60.png
# automobile_61.png
# automobile_62.png
# automobile_63.png
# automobile_64.png
# automobile_65.png
# automobile_66.png
# automobile_67.png
# automobile_68.png
# automobile_69.png
# automobile_7.png
# automobile_70.png
# automobile_71.png
# automobile_72.png
# automobile_73.png
# automobile_74.png
# automobile_75.png
# automobile_76.png
# automobile_77.png
# automobile_78.png
# automobile_79.png
# automobile_8.png
# automobile_80.png
# automobile_81.png
# automobile_82.png
# automobile_83.png
# automobile_84.png
# automobile_85.png
# automobile_86.png
# automobile_87.png
# automobile_88.png
# automobile_89.png
# automobile_9.png
# automobile_90.png
# automobile_91.png
# automobile_92.png
# automobile_93.png
# automobile_94.png
# automobile_95.png
# automobile_96.png
# automobile_97.png
# automobile_98.png
# automobile_99.png
# bird_1.png
# bird_10.png
# bird_100.png
# bird_101.png
# bird_102.png
# bird_103.png
# bird_104.png
# bird_105.png
# bird_106.png
# bird_107.png
# bird_108.png
# bird_109.png
# bird_11.png
# bird_110.png
# bird_111.png
# bird_112.png
# bird_113.png
# bird_114.png
# bird_115.png
# bird_116.png
# bird_117.png
# bird_118.png
# bird_119.png
# bird_12.png
# bird_120.png
# bird_121.png
# bird_122.png
# bird_123.png
# bird_124.png
# bird_125.png
# bird_126.png
# bird_127.png
# bird_128.png
# bird_129.png
# bird_13.png
# bird_130.png
# bird_131.png
# bird_132.png
# bird_133.png
# bird_134.png
# bird_135.png
# bird_136.png
# bird_137.png
# bird_138.png
# bird_139.png
# bird_14.png
# bird_140.png
# bird_141.png
# bird_142.png
# bird_143.png
# bird_144.png
# bird_145.pn

# %% [markdown]
# #3. Show pictures

# %%
import matplotlib.pyplot as plt
import random
import numpy as np
from PIL import Image
import os

categoriesList=["airplane","automobile","bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

def plotImagesMount(n_images=8):
    fig, axes = plt.subplots(n_images, n_images, figsize=(9,9))
    axes = axes.flatten()
    
    for i in range(n_images * n_images):
        rand1 = random.randint(0, 9)
        rand2 = random.randint(1, 200)
        filename=str(categoriesList[rand1]) + "_" + str(rand2)
        filenamepng=filename + ".png"
        img = Image.open(os.path.join("/dbfs/mnt/" + mountname + "/", filenamepng))
        ax = axes[i]
    
        ax.imshow( img, cmap="Greys_r")
        ax.set_xticks(())
        ax.set_yticks(())
        
        ax.set_title(filename, fontsize=18 - n_images)
        
    plot = plt.tight_layout()
    return plot
  
display(plotImagesMount(n_images=10))
